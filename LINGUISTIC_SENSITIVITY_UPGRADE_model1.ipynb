# %%
! pip install tensorflow_text
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 92.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 115.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 49.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
# ...

# %%
# !pip install kaggle

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d mrmorj/hate-speech-and-offensive-language-dataset
# Out:
# ...
#   0% 0.00/1.01M [00:00<?, ?B/s]
# 100% 1.01M/1.01M [00:00<00:00, 149MB/s]

# %%
import pandas as pd

# %%
! unzip /content/hate-speech-and-offensive-language-dataset.zip
# Out:
# Archive:  /content/hate-speech-and-offensive-language-dataset.zip
#   inflating: labeled_data.csv

# %%
data = pd.read_csv("labeled_data.csv")

# %%
data
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
#  2   hate_speech         24783 non-null  int64
#  3   offensive_language  24783 non-null  int64
#  4   neither             24783 non-null  int64
#  5   class               24783 non-null  int64
#  6   tweet               24783 non-null  object
# dtypes: int64(6), object(1)
# memory usage: 1.3+ MB

# %%
data.describe()
# Out:
#          Unnamed: 0         count   hate_speech  offensive_language  \
# count  24783.000000  24783.000000  24783.000000        24783.000000
# mean   12681.192027      3.243473      0.280515            2.413711
# std     7299.553863      0.883060      0.631851            1.399459
# min        0.000000      3.000000      0.000000            0.000000
# 25%     6372.500000      3.000000      0.000000            2.000000
# 50%    12703.000000      3.000000      0.000000            3.000000
# 75%    18995.500000      3.000000      0.000000            3.000000
# max    25296.000000      9.000000      7.000000            9.000000
#
#             neither         class
# count  24783.000000  24783.000000
# mean       0.549247      1.110277
# std        1.113299      0.462089
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        0.000000      1.000000
# 75%        0.000000      1.000000
# max        9.000000      2.000000

# %% [markdown]
# #Classes
# 1.Hate Speech
#
# 2.Offensive Language
#
# 3.No Hate and Offensive

# %%
data_df=data[["class","tweet"]]

# %%
data_df
# Out:
#        class                                              tweet
# 0          2  !!! RT @mayasolovely: As a woman you shouldn't...
# 1          1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2          1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3          1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4          1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...      ...                                                ...
# 24778      1  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779      2  you've gone and broke the wrong heart baby, an...
# 24780      1  young buck wanna eat!!.. dat nigguh like I ain...
# 24781      1              youu got wild bitches tellin you lies
# 24782      2  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 2 columns]

# %%
data_df.loc[data_df['class'] == 1, 'class'] = 3

# %%
data_df.loc[data_df['class'] == 3, 'class'] = 0

# %%
data_df.loc[data_df['class'] == 2, 'class'] = 1

# %%
data_df
# Out:
#        class                                              tweet
# 0          1  !!! RT @mayasolovely: As a woman you shouldn't...
# 1          0  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2          0  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3          0  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4          0  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...      ...                                                ...
# 24778      0  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779      1  you've gone and broke the wrong heart baby, an...
# 24780      0  young buck wanna eat!!.. dat nigguh like I ain...
# 24781      0              youu got wild bitches tellin you lies
# 24782      1  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 2 columns]

# %% [markdown]
# #Now
# 0=>Offensive
#
# 1=>not offensive

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   class   24783 non-null  int64
#  1   tweet   24783 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 387.4+ KB

# %%
data_df.rename(columns={'class': 'offensive'}, inplace=True)
# Out:
# <ipython-input-28-bcfb9a7bbfdb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df.rename(columns={'class': 'offensive'}, inplace=True)

# %%
data_df
# Out:
#        offensive                                              tweet
# 0              1  !!! RT @mayasolovely: As a woman you shouldn't...
# 1              0  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2              0  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3              0  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4              0  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...          ...                                                ...
# 24778          0  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779          1  you've gone and broke the wrong heart baby, an...
# 24780          0  young buck wanna eat!!.. dat nigguh like I ain...
# 24781          0              youu got wild bitches tellin you lies
# 24782          1  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 2 columns]
# ...

# %%
data_df.offensive.value_counts()
# Out:
# 0    20620
# 1     4163
# Name: offensive, dtype: int64

# %%
data_df[data_df['offensive'] == 1]
# Out:
#        offensive                                              tweet
# 0              1  !!! RT @mayasolovely: As a woman you shouldn't...
# 40             1    " momma said no pussy cats inside my doghouse "
# 63             1  "@Addicted2Guys: -SimplyAddictedToGuys http://...
# 66             1  "@AllAboutManFeet: http://t.co/3gzUpfuMev" woo...
# 67             1  "@Allyhaaaaa: Lemmie eat a Oreo &amp; do these...
# ...          ...                                                ...
# 24736          1  yaya ho.. cute avi tho RT @ViVaLa_Ari I had no...
# 24737          1  yea so about @N_tel 's new friend.. all my fri...
# 24767          1  you know what they say, the early bird gets th...
# 24779          1  you've gone and broke the wrong heart baby, an...
# 24782          1  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [4163 rows x 2 columns]

# %%
data_df.loc[:, 'tweet'] = data_df['tweet'].str.replace(r'@.*?:', '', regex=True)
data_df
# Out:
# <ipython-input-32-d82d435d4dc0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_df.loc[:, 'tweet'] = data_df['tweet'].str.replace(r'@.*?:', '', regex=True)
#        offensive                                              tweet
# 0              1  !!! RT  As a woman you shouldn't complain abou...
# 1              0  !!!!! RT  boy dats cold...tyga dwn bad for cuf...
# 2              0  !!!!!!! RT  You ever fuck a bitch and she star...
# 3              0   !!!!!!!!! RT  @viva_based she look like a tranny
# 4              0  !!!!!!!!!!!!! RT  The shit you hear about me m...
# ...          ...                                                ...
# 24778          0  you's a muthaf***in lie &#8220; @20_Pearls @co...
# ...

# %%
data_df[data_df.offensive ==1]
# Out:
#        offensive                                              tweet
# 0              1  !!! RT  As a woman you shouldn't complain abou...
# 40             1    " momma said no pussy cats inside my doghouse "
# 63             1  " -SimplyAddictedToGuys http://t.co/1jL4hi8ZMF...
# 66             1  " http://t.co/3gzUpfuMev" woof woof and hot soles
# 67             1  " Lemmie eat a Oreo &amp; do these dishes." On...
# ...          ...                                                ...
# 24736          1  yaya ho.. cute avi tho RT @ViVaLa_Ari I had no...
# 24737          1  yea so about @N_tel 's new friend.. all my fri...
# 24767          1  you know what they say, the early bird gets th...
# 24779          1  you've gone and broke the wrong heart baby, an...
# 24782          1  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [4163 rows x 2 columns]

# %%
data_df[data_df.offensive ==0]
# Out:
#        offensive                                              tweet
# 1              0  !!!!! RT  boy dats cold...tyga dwn bad for cuf...
# 2              0  !!!!!!! RT  You ever fuck a bitch and she star...
# 3              0   !!!!!!!!! RT  @viva_based she look like a tranny
# 4              0  !!!!!!!!!!!!! RT  The shit you hear about me m...
# 5              0  !!!!!!!!!!!!!!!!!!" The shit just blows me..cl...
# ...          ...                                                ...
# 24776          0                                 you're all niggers
# 24777          0  you're such a retard i hope you get type 2 dia...
# 24778          0  you's a muthaf***in lie &#8220; @20_Pearls @co...
# 24780          0  young buck wanna eat!!.. dat nigguh like I ain...
# 24781          0              youu got wild bitches tellin you lies
#
# [20620 rows x 2 columns]

# %%
data_df
# Out:
#        offensive                                              tweet
# 0              1  !!! RT  As a woman you shouldn't complain abou...
# 1              0  !!!!! RT  boy dats cold...tyga dwn bad for cuf...
# 2              0  !!!!!!! RT  You ever fuck a bitch and she star...
# 3              0   !!!!!!!!! RT  @viva_based she look like a tranny
# 4              0  !!!!!!!!!!!!! RT  The shit you hear about me m...
# ...          ...                                                ...
# 24778          0  you's a muthaf***in lie &#8220; @20_Pearls @co...
# 24779          1  you've gone and broke the wrong heart baby, an...
# 24780          0  young buck wanna eat!!.. dat nigguh like I ain...
# 24781          0              youu got wild bitches tellin you lies
# 24782          1  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 2 columns]

# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub

# %%
from sklearn.model_selection import train_test_split

# %%
train_df,valid_df = train_test_split(data_df,random_state=42,train_size=0.25,stratify=data_df.offensive.values)
train_df.shape,valid_df.shape
# Out:
# ((6195, 2), (18588, 2))

# %%
train_df.offensive.value_counts()
# Out:
# 0    5154
# 1    1041
# Name: offensive, dtype: int64

# %%
valid_df.offensive.value_counts()
# Out:
# 0    15466
# 1     3122
# Name: offensive, dtype: int64

# %%
train_data = tf.data.Dataset.from_tensor_slices((train_df.tweet.values, train_df.offensive.values))
valid_data = tf.data.Dataset.from_tensor_slices((valid_df.tweet.values, valid_df.offensive.values))

# %%
import tensorflow_hub as hub
import tensorflow_text

bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
bert_encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4")

# %%
text_input = tf.keras.layers.Input(shape=[], dtype=tf.string, name='text')
preprocessed_text = bert_preprocess(text_input)
outputs = bert_encoder(preprocessed_text)

# Neural network layers
l = tf.keras.layers.Dropout(0.1, name="dropout")(outputs['pooled_output'])
l = tf.keras.layers.Dense(1, activation='sigmoid', name="output")(l)

# Use inputs and outputs to construct a final model
model = tf.keras.Model(inputs=[text_input], outputs = [l])

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall')
]

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=METRICS)

# %%
X_train, X_test, y_train, y_test = train_test_split(data_df['tweet'],data_df['offensive'], stratify=data_df['offensive'])

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((18587,), (6196,), (18587,), (6196,))

# %%
model.fit(X_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# 581/581 [==============================] - 211s 341ms/step - loss: 0.4103 - accuracy: 0.8332 - precision: 0.5745 - recall: 0.0259
# Epoch 2/3
# 581/581 [==============================] - 201s 345ms/step - loss: 0.3639 - accuracy: 0.8444 - precision: 0.7010 - recall: 0.1284
# Epoch 3/3
# 581/581 [==============================] - 200s 345ms/step - loss: 0.3423 - accuracy: 0.8526 - precision: 0.7194 - recall: 0.2012

# %%
model.save('model1.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
predict=model.predict(X_test)
# Out:
# 194/194 [==============================] - 71s 362ms/step

# %%
model.evaluate(X_test,y_test)
# Out:
# 194/194 [==============================] - 68s 345ms/step - loss: 0.3254 - accuracy: 0.8614 - precision: 0.7264 - recall: 0.2805
# [0.32535669207572937,
#  0.8613621592521667,
#  0.7263681888580322,
#  0.28049951791763306]

# %%
y_test["predicted"]=predict
y_test
# Out:
# 18578                                                        0
# 3715                                                         0
# 7455                                                         0
# 15151                                                        0
# 11408                                                        0
#                                    ...
# 23422                                                        0
# 20844                                                        0
# 21697                                                        0
# 16110                                                        0
# predicted    [[0.14681318], [0.3021233], [0.110765316], [0....
# Name: offensive, Length: 6197, dtype: object

# %%
ydata=pd.DataFrame(y_test)
ydata=ydata.iloc[:-1]

# %%
ydata["predicted"]=predict
ydata
# Out:
#       offensive  predicted
# 18578         0   0.146813
# 3715          0   0.302123
# 7455          0   0.110765
# 15151         0   0.561379
# 11408         0   0.264296
# ...         ...        ...
# 18257         0   0.049264
# 23422         0   0.088595
# 20844         0   0.207590
# 21697         0   0.167686
# 16110         0   0.057045
#
# [6196 rows x 2 columns]

# %%
ydata=ydata.sort_values(by="offensive")

# %% [markdown]
# # Calculate the lower and upper quantiles for the 85% interval

# %%
mean_offensive=ydata.loc[ydata.offensive == 0].mean()
lower_offensive=ydata.loc[ydata.offensive == 0].quantile(0.075)
upper_offensive=ydata.loc[ydata.offensive == 0].quantile(0.925)
lower_offensive,upper_offensive,mean_offensive
# Out:
# <ipython-input-121-c7d6d597371f>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   lower_offensive=ydata.loc[ydata.offensive == 0].quantile(0.075)
# <ipython-input-121-c7d6d597371f>:3: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   upper_offensive=ydata.loc[ydata.offensive == 0].quantile(0.925)
# (predicted    0.028983
#  Name: 0.075, dtype: float64,
#  predicted    0.359556
#  Name: 0.925, dtype: float64,
#  offensive    0.000000
#  predicted    0.148128
#  dtype: float64)

# %%
mean_not_offensive=ydata.loc[ydata.offensive == 1].mean()
lower_not_offensive=ydata.loc[ydata.offensive == 1].quantile(0.075)
upper_not_offensive=ydata.loc[ydata.offensive == 1].quantile(0.925)
lower_not_offensive,upper_not_offensive,mean_not_offensive
# Out:
# <ipython-input-122-0b38fc45771e>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   lower_not_offensive=ydata.loc[ydata.offensive == 1].quantile(0.075)
# <ipython-input-122-0b38fc45771e>:3: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   upper_not_offensive=ydata.loc[ydata.offensive == 1].quantile(0.925)
# (predicted    0.138931
#  Name: 0.075, dtype: float64,
#  predicted    0.674099
#  Name: 0.925, dtype: float64,
#  offensive    1.000000
#  predicted    0.390078
#  dtype: float64)

# %%
required_limit=(upper_offensive+lower_not_offensive)/2
required_limit
# Out:
# predicted    0.249243
# dtype: float64

# %%
model.predict(["You are a bitch"])
# Out:
# 1/1 [==============================] - 0s 59ms/step
# array([[0.06035188]], dtype=float32)

# %%
model.predict(["Who wants to get there nose in these bad bois then #scally #chav #sockfetish #stinking http://t.co/FeQxgN0W6I hot sox and legs1"])
# Out:
# 1/1 [==============================] - 0s 162ms/step
# array([[0.21198432]], dtype=float32)
